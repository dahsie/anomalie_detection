# %% [markdown]
# # Analyse du jeu de données de fraudes banquaires issu de Kaggle
#
# Le jeu de données est diponible sur Kaggle via le lien ci-dessous
#
# "https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud/"

# %% [markdown]
# ### 1. Analyse exploratoire du jeu de données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math 

#For data visualization
from sklearn.decomposition import PCA,TruncatedSVD,KernelPCA
from sklearn.manifold import TSNE

# %%
data=pd.read_csv("/home/dah/anomalie_detection/anomalie_detection/data/creditcard.csv")

# %%
data=data.copy(deep=True)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# Les données ne contiennent pas de valeurs nulles au vu de la sortie de data.info()
#
# Cette dataset issu de Kaggle semble être déjà néttoyé des valeurs nulles ou valeurs manquantes
#
# Celle ce confirme par la sortie de "data[data.isnull().any(axis=1)]" qui ne renvoie aucune ligne

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
fix,axes=plt.subplots(1,2,figsize=(12,5))
data.Class.value_counts(normalize=True).plot(kind="pie",ax=axes[0])
axes[0].set_title("pie char")
data.Class.value_counts(normalize=True).plot(kind="bar",ax=axes[1])
axes[1].set_title("bar char")
plt.show()

# %%
data.Class.unique()
# Out:
# array([0, 1])

# %% [markdown]
# #### Analyse de la propotion des anomalies
# Le jeu de données renfermme seulement 0.1727% d'anomalies

# %%
l=list(data.Class.value_counts())
cross_tab=pd.DataFrame(
    {"0":[l[0]],
    "1":[l[1]],
    "total":[l[0]+l[1]]
   })
cross_tab
# Out:
#         0    1   total
# 0  284315  492  284807

# %%
prop_1=cross_tab.iloc[0,1]/cross_tab.iloc[0,2]
prop_1*100
# Out:
# 0.1727485630620034

# %%
data[data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# #### vérification de doublons

# %%
duplicated=data[data.duplicated(keep=False)]

# %% [markdown]
# Le jeu de données contient assez de doublons <br>
# La ligne ci-dessous permet de constater qu'il y a 1854 lignes de doublons. ce qui repressente 0.65 % du jeu de données inial

# %%
duplicated.head(20)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 32      26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 33      26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 34      26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 35      26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 112     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 113     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115     74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 220    145.0 -2.420413  1.947885  0.553646  0.983069 -0.281518  2.408958
# 221    145.0 -2.420413  1.947885  0.553646  0.983069 -0.281518  2.408958
# 222    145.0 -2.419486  1.949346  0.552998  0.982710 -0.284815  2.411200
# 223    145.0 -2.419486  1.949346  0.552998  0.982710 -0.284815  2.411200
# ...

# %%
duplicated.shape
# Out:
# (1854, 31)

# %%
(duplicated.shape[0]/data.shape[0])*100
# Out:
# 0.6509671461726713

# %%
duplicated.describe()
# Out:
#                 Time           V1           V2           V3           V4  \
# count    1854.000000  1854.000000  1854.000000  1854.000000  1854.000000
# mean    94448.014024    -1.550730     1.043475    -0.443509     0.712007
# std     48781.945109     3.458374     2.335770     2.769019     1.606427
# min        26.000000   -26.457745   -15.289166   -30.177317    -3.223176
# 25%     53484.000000    -2.581315    -0.147441    -1.260573    -0.380098
# 50%     84149.000000    -1.203617     0.872543     0.111028     0.526622
# 75%    142583.000000     1.138387     1.938769     1.027314     1.373592
# max    172233.000000     2.178710    16.497472     3.031897    10.648505
#
#                 V5           V6           V7           V8           V9  ...  \
# count  1854.000000  1854.000000  1854.000000  1854.000000  1854.000000  ...
# mean     -0.505289     0.264623    -0.455491     0.311091     0.404644  ...
# std       1.970398     1.349820     2.554122     2.985528     1.605576  ...
# ...

# %% [markdown]
# #### Suppresion des doublons

# %%
data.drop_duplicates(keep="last",inplace=True)

# %%
data.head(50)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %%
data.shape
# Out:
# (283726, 31)

# %% [markdown]
# #### Porportion des anomalies après la suppression des doublons
# La proportion des anormales est passé de 0.1727% à 0.1667 après la suppression des doublons

# %%
l=list(data.Class.value_counts())
cross_tab=pd.DataFrame(
    {"0":[l[0]],
    "1":[l[1]],
    "total":[l[0]+l[1]]
   })
print(cross_tab)

prop_1=cross_tab.iloc[0,1]/cross_tab.iloc[0,2]
print(prop_1*100)
# Out:
#         0    1   total
# 0  283253  473  283726
# 0.1667101358352777

# %% [markdown]
# ### Analyse de valeurs abérrantes
# Par exemple des montant négatives lors d'une transation<br>
# Une question se pose aussi sur des transation dont le montant est nul. <br>
# Que signifie alors une transation de montant nul ? Est-ce une transation réfusé ?<br>
#
# Le montant minimal ici est nul, ce qui est rassurant <br>
# Il y a plusieurs transation de montant nul. <br>
# Une seule valeur maximal est rencontrer dans le jeu donnée. Cette valeur pourrait être une valeur abérrantes.<br>

# %%
data[data.Amount==data.Amount.min()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 383        282.0 -0.356466  0.725418  1.971749  0.831343  0.369681 -0.107776
# 514        380.0 -1.299837  0.881817  1.452842 -1.293698 -0.025105 -1.170103
# 534        403.0  1.237413  0.512365  0.687746  1.693872 -0.236323 -0.650232
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 575        430.0 -1.860258 -0.629859  0.966570  0.844632  0.759983 -1.481173
# ...          ...       ...       ...       ...       ...       ...       ...
# 283719  171817.0 -0.750414  0.904175  0.996461  0.427284  1.720336  0.929256
# 283782  171870.0  2.083677 -0.065811 -1.442870  0.135416  0.043035 -1.306975
# 283949  172027.0  2.132569 -0.057836 -1.724522 -0.030326  0.412146 -0.903088
# 284085  172140.0 -2.210521 -1.039425  0.189704 -1.291932  3.742120 -1.665061
# 284770  172759.0 -0.822731  1.270140 -0.138566  0.479620  1.242101  0.795218
#
# ...

# %%
data[data.Amount==0].Class.value_counts()
# Out:
# Class
# 0    1783
# 1      25
# Name: count, dtype: int64

# %%
data[data.Amount==data.Amount.max()]
# Out:
#             Time         V1         V2         V3         V4          V5  \
# 274771  166198.0 -35.548539 -31.850484 -48.325589  15.304184 -113.743307
#
#                V6          V7        V8        V9  ...       V21       V22  \
# 274771  73.301626  120.589494 -27.34736 -3.872425  ... -21.62012  5.712303
#
#              V23       V24       V25       V26        V27        V28  \
# 274771 -1.581098  4.584549  4.554683  3.415636  31.612198 -15.430084
#
#           Amount  Class
# 274771  25691.16      0
#
# [1 rows x 31 columns]

# %%
data.Amount.sort_values()
# Out:
# 84293         0.00
# 219965        0.00
# 219958        0.00
# 56576         0.00
# 23856         0.00
#             ...
# 54018     11898.09
# 46841     12910.93
# 151296    18910.00
# 58465     19656.53
# 274771    25691.16
# Name: Amount, Length: 283726, dtype: float64

# %%
fig, axes=plt.subplots(1,2,figsize=(12,5))
axes[0].plot(data.Amount)

axes[1].boxplot(data.Amount)
plt.show()

# %%
# Utiliser des indices de colonnes pour accéder aux axes dans la grille
n,p=data.shape[0],data.shape[1] -2

fix,axes=plt.subplots(7,4,figsize=(30,30))
for i in range(7):
    for j in range(4):
        index = i * 4 + j + 1
        if index <= p:
            feature = f"V{index}"
            axes[i, j].plot(data[feature])
            axes[i, j].set_title(f'V{index}')

plt.tight_layout()
plt.show()

# %%
n,p=data.shape[0],data.shape[1] -2

fix,axes=plt.subplots(7,4,figsize=(30,30))
for i in range(7):
    for j in range(4):
        index = i * 4 + j + 1
        if index <= p:
            feature = f"V{index}"
            axes[i, j].boxplot(data[feature])
            axes[i, j].set_title(f'V{index}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization des données

# %% [markdown]
# #### 1. PCA

# %%
target=data.Class
xtrain=data.drop(["Time","Amount","Class"],axis=1)

# %%
pca=PCA(n_components=2,random_state=42)

# %%
params=pca.get_params()
for name, value in params.items():
    print(f"{name}  {value}")
# Out:
# copy  True
# iterated_power  auto
# n_components  2
# n_oversamples  10
# power_iteration_normalizer  auto
# random_state  42
# svd_solver  auto
# tol  0.0
# whiten  False

# %%
pca_data=pca.fit_transform(xtrain)

# %%
print(f"variance expliquée {pca.explained_variance_ratio_}")
print(f"échantillons {pca.n_samples_}")
# Out:
# variance expliquée [0.1245754  0.08900086]
# échantillons 283726

# %% [markdown]
# Les deux composantes proncipales ne parviennet pas à expliquer une grande partie de la variance. Elles explique que 20% de celle-ci.<br>
# Il faut tenter une autre approche pour mieux visualizer la données.

# %%
pca_data.shape
# Out:
# (283726, 2)

# %%
plt.scatter(pca_data[target == 0, 0], pca_data[target == 0, 1], c='blue', label='Normale')
plt.scatter(pca_data[target == 1, 0], pca_data[target == 1, 1], c='red', label='Anormale')

plt.title("PCA")
plt.legend()  # Ajoute la légende
plt.show()

# %%
tsvd=TruncatedSVD(n_components=2,random_state=42)
tsvd_data=tsvd.fit_transform(xtrain)

# %%
plt.scatter(tsvd_data[target == 0, 0], tsvd_data[target == 0, 1], c='blue', label='Normale')
plt.scatter(tsvd_data[target == 1, 0], tsvd_data[target == 1, 1], c='red', label='Anormale')

plt.title("TruncatedSVD")
plt.legend()  # Ajoute la légende
plt.show()

# %%
kpca=KernelPCA(kernel='rbf',n_components=2,random_state=42)
kpca_data=tsvd.fit_transform(xtrain)

# %%
plt.scatter(kpca_data[target == 0, 0], kpca_data[target == 0, 1], c='blue', label='Normale')
plt.scatter(kpca_data[target == 1, 0], kpca_data[target == 1, 1], c='red', label='Anormale')

plt.title("Kernel PCA")
plt.legend()  # Ajoute la légende
plt.show()

# %% [markdown]
# #### 2. TSNE

# %%
tsne=TSNE(n_components=2,random_state=42,init="pca",verbose=1,n_jobs=-1)

# %%
tsne_data=tsne.fit_transform(xtrain)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 283726 samples in 0.026s...
# [t-SNE] Computed neighbors for 283726 samples in 49.727s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 283726
# [t-SNE] Computed conditional probabilities for sample 2000 / 283726
# [t-SNE] Computed conditional probabilities for sample 3000 / 283726
# [t-SNE] Computed conditional probabilities for sample 4000 / 283726
# [t-SNE] Computed conditional probabilities for sample 5000 / 283726
# [t-SNE] Computed conditional probabilities for sample 6000 / 283726
# [t-SNE] Computed conditional probabilities for sample 7000 / 283726
# [t-SNE] Computed conditional probabilities for sample 8000 / 283726
# [t-SNE] Computed conditional probabilities for sample 9000 / 283726
# [t-SNE] Computed conditional probabilities for sample 10000 / 283726
# [t-SNE] Computed conditional probabilities for sample 11000 / 283726
# [t-SNE] Computed conditional probabilities for sample 12000 / 283726
# ...

# %%
plt.scatter(tsne_data[target == 0, 0], tsne_data[target == 0, 1], c='blue', label='Normale')
plt.scatter(tsne_data[target == 1, 0], tsne_data[target == 1, 1], c='red', label='Anormale')

plt.title("TSNE")
plt.legend()  # Ajoute la légende
plt.show()

# %% [markdown]
# ### Questions ?
# 1. Les données doivent être tranfromées en incluant le feature Amount ou non ?
# 2. Est-ce la bonne representation des données ?
# 3. Quelles autres permetteraient de mieux visualiser les données ?
# 4. Les différentes representations des données ne semble pas être approprié pour <br>
#    la visualisation des données car les données normales ne se distinguent pas des anomalies
